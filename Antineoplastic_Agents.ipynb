# %% [markdown]
# # Antineoplastic Agents Exposure Analysis

# %% [markdown]
# ## Introduction

# %% [markdown]
# Antineoplastic agents (ADs), commonly known as chemotherapy or cytotoxic drugs, are crucial in cancer treatment. These agents disrupt the cell cycle and kill rapidly dividing cells, such as cancer cells. However, their high toxicity presents significant risks not only to patients, but also healthcare workers.
#
# This project analyzes data from the The Alberta and Minnesota Antineoplastic Drug Surveillance Database. Managed by the University of British Columbia, School of Population and Public Health, it contains measurement observations of AD contamination at nine cancer sites in both Alberta (AB) and Minnesota (MN) from 2018-2019.
#
# The primary objective of this research is to survey the AD exposure levels on common surfaces at these facilities, and assess the associated risks to healthcare workers. Specifically, the project aims to answer the following question:
#
# ##### "What antineoplastic agents were found on the most commonly contaminated workplace surfaces for the participating nine sites?"

# %% [markdown]
# ## 1. Import Libraries

# %%
import pandas as pd
import numpy as np
import altair as alt

# %% [markdown]
# ## 2. Uploading the Data

# %%
path = "/Users/eunicebalicanta/Occupational Health Risk of Antineoplastic Agents Project/jend-ohs-futures-alberta-minnesota-antineoplastic-drug-surveillance-database.xlsx"

# %%
meta = pd.read_excel (path, "Metadata")
meta
# Out:
#                 METADATA                                         Unnamed: 1
# 0                    NaN                                                NaN
# 1                    NaN                                                NaN
# 2                Element                                              Notes
# 3                  Title  Alberta and Minnesota Antineoplastic Drug Surv...
# 4                Creator  Univeristy of British Columbia, School of Popu...
# 5            Description  Contains measurement observations and suppleme...
# 6                    NaN                                                NaN
# 7           Contact Name                                    Dr. Hugh Davies
# 8          Contact Email                                 hugh.davies@ubc.ca
# 9                    NaN                                                NaN
# 10      Update Frequency                                                NaN
# 11           Date Issued                                          4/20/2020
# 12          Date Created                                         05/28/2019
# 13            Start Date                                         06/11/2018
# 14              End Date                                         05/24/2019
# 15      Spatial Coverage  Alberta, Canada and Minnesota, USA over a 12 m...
# 16  Usage Considerations            No restriction after any embargo period

# %%
df = pd.read_excel (path, "Data")
df
# Out:
#        row    s_code  site  siteID                month  monthID  sampleID  \
# 0        1    W1-1-1   Edm       1  2018-06-01 00:00:00        1         1
# 1        2    W1-1-2   Edm       1  2018-06-01 00:00:00        1         2
# 2        3    W1-1-3   Edm       1  2018-06-01 00:00:00        1         3
# 3        4    W1-1-4   Edm       1  2018-06-01 00:00:00        1         4
# 4        5    W1-1-5   Edm       1  2018-06-01 00:00:00        1         5
# ...    ...       ...   ...     ...                  ...      ...       ...
# 1991  1992  W9-12-21  UMMC       9                  May       12        21
# 1992  1993  W9-12-22  UMMC       9                  May       12        22
# 1993  1994  W9-12-23  UMMC       9                  May       12        23
# 1994  1995  W9-12-24  UMMC       9                  May       12        24
# 1995  1996  W9-12-25  UMMC       9                  May       12        25
#
#          day time_day                         surface  ... n_spill  \
# 0     Friday       PM               Receiving counter  ...       0
# 1     Friday       PM        Room temperature Storage  ...       0
# 2     Friday       PM    Hazardous Drug Fridge Handle  ...       0
# 3     Friday       PM                     Set-up Area  ...       0
# 4     Friday       PM             Pass-through Handle  ...       0
# ...      ...      ...                             ...  ...     ...
# 1991  Friday       AM                         scanner  ...       1
# 1992  Friday       AM            workstation keyboard  ...       1
# 1993  Friday       AM       storage cart patient room  ...       1
# 1994  Friday       AM    patient washroom door handle  ...       1
# 1995  Friday       AM  patient washroom toilet handle  ...       1
#
#                  n_spillC  n_cond  n_condC  n_other  \
# 0                     -99       5      -99      -99
# 1                     -99       5      -99      -99
# 2                     -99       5      -99      -99
# 3                     -99       5      -99      -99
# 4                     -99       5      -99      -99
# ...                   ...     ...      ...      ...
# 1991  spill in last month       3      -99      -99
# 1992  spill in last month       3      -99      -99
# 1993  spill in last month       3      -99      -99
# 1994  spill in last month       3      -99      -99
# 1995  spill in last month       3      -99      -99
#
#                                notes  location  handles  BSC  transport
# 0                               1645         2        0    0          0
# 1             1655: fluorouracil bin         2        0    0          0
# 2                               1710         2        1    0          0
# 3                               1715         2        0    0          0
# 4     1725; bottom right hand corner         1        1    0          1
# ...                              ...       ...      ...  ...        ...
# 1991                             -99         3        0    0          0
# 1992                             -99         3        0    0          0
# 1993                             -99         5        0    0          0
# 1994                             -99         5        0    0          0
# 1995                             -99         5        0    0          0
#
# [1996 rows x 125 columns]

# %%
df.columns
# Out:
# Index(['row', 's_code', 'site', 'siteID', 'month', 'monthID', 'sampleID',
#        'day', 'time_day', 'surface',
#        ...
#        'n_spill', 'n_spillC', 'n_cond', 'n_condC', 'n_other', 'notes',
#        'location', 'handles', 'BSC', 'transport'],
#       dtype='object', length=125)

# %% [markdown]
# ## 3. Cleaning and Exploring the Dataset

# %%
df_filtered = df.filter(items=['site','surface','p_surfaceID', 'gem_mass', 'fu_mass', 'ox_mass', 'mtrx_mass', 'ifos_mass', 'cycl_mass', 
                     'vinc_mass', 'vinb_mass', 'brtz_mass', 'docx_mass', 'pacx_mass'])
df_filtered
# Out:
#       site                         surface p_surfaceID   gem_mass  fu_mass  \
# 0      Edm               Receiving counter      hd_rec -77.000000    -77.0
# 1      Edm        Room temperature Storage   hd_rmtemp   0.125430    -77.0
# 2      Edm    Hazardous Drug Fridge Handle   hd_fridge -77.000000    -77.0
# 3      Edm                     Set-up Area       setup   0.168720    -77.0
# 4      Edm             Pass-through Handle   pt_handle   0.102675    -77.0
# ...    ...                             ...         ...        ...      ...
# 1991  UMMC                         scanner     scanner -77.000000    -77.0
# 1992  UMMC            workstation keyboard       n_key -77.000000    -77.0
# 1993  UMMC       storage cart patient room     pt_side -77.000000    -77.0
# 1994  UMMC    patient washroom door handle   pt_wrdoor -77.000000    -77.0
# 1995  UMMC  patient washroom toilet handle   pt_toilet -77.000000    -77.0
#
#       ox_mass  mtrx_mass  ifos_mass  cycl_mass  vinc_mass  vinb_mass  \
# 0       -77.0      -77.0      -77.0   32.98809 -77.000000  -77.00000
# 1       -77.0      -77.0      -77.0  -77.00000 -77.000000  -77.00000
# 2       -77.0      -77.0      -77.0  -77.00000   0.930735  -77.00000
# 3       -77.0      -77.0      -77.0  -77.00000 -77.000000  -77.00000
# 4       -77.0      -77.0      -77.0  -77.00000 -77.000000    0.33078
# ...       ...        ...        ...        ...        ...        ...
# 1991    -77.0      -77.0      -77.0  -77.00000 -77.000000  -77.00000
# 1992    -77.0      -77.0      -77.0  -77.00000 -77.000000  -77.00000
# 1993    -77.0      -77.0      -77.0  -77.00000 -77.000000  -77.00000
# 1994    -77.0      -77.0      -77.0  -77.00000 -77.000000  -77.00000
# 1995    -77.0      -77.0      -77.0  -77.00000 -77.000000  -77.00000
#
#       brtz_mass  docx_mass  pacx_mass
# 0         -77.0  -77.00000      -77.0
# 1         -77.0  -77.00000      -77.0
# 2         -77.0  -77.00000      -77.0
# 3         -77.0    0.25568      -77.0
# 4         -77.0  -77.00000      -77.0
# ...         ...        ...        ...
# 1991      -77.0  -77.00000      -77.0
# 1992      -77.0  -77.00000      -77.0
# 1993      -77.0  -77.00000      -77.0
# 1994      -77.0  -77.00000      -77.0
# 1995      -77.0  -77.00000      -77.0
#
# [1996 rows x 14 columns]

# %%
n = 5
top_5_surfaces = df['p_surfaceID'].value_counts()[:n].index.tolist()
top_5_surfaces
# Out:
# ['n_key', 'bsc', 'pt_side', 'pt_surf', 'n_cnt']

# %%
conditions = (
    (df_filtered['p_surfaceID'] == 'n_key') |
    (df_filtered['p_surfaceID'] == 'bsc') |
    (df_filtered['p_surfaceID'] == 'pt_side') |
    (df_filtered['p_surfaceID'] == 'pt_surf') |
    (df_filtered['p_surfaceID'] == 'n_cnt')
)

df_top_5_surfaces = df_filtered[conditions].copy() 
df_top_5_surfaces.reset_index(drop=True, inplace=True)
df_top_5_surfaces
# Out:
#      site                       surface p_surfaceID  gem_mass  fu_mass  \
# 0     Edm             Pass-through Tray     pt_surf     -77.0    -77.0
# 1     Edm              BSC work Surface         bsc     -77.0    -77.0
# 2     Edm               Nursing counter       n_cnt     -77.0    -77.0
# 3     Edm                    Side table     pt_side     -77.0    -77.0
# 4     Edm  Nursing workstation keyboard       n_key     -77.0    -77.0
# ..    ...                           ...         ...       ...      ...
# 545  UMMC           passthrough surface     pt_surf     -77.0    -77.0
# 546  UMMC             plastic chemo bin     pt_surf     -77.0    -77.0
# 547  UMMC                           BSC         bsc     -77.0    -77.0
# 548  UMMC          workstation keyboard       n_key     -77.0    -77.0
# 549  UMMC     storage cart patient room     pt_side     -77.0    -77.0
#
#      ox_mass  mtrx_mass  ifos_mass   cycl_mass  vinc_mass  vinb_mass  \
# 0      -77.0 -77.000000 -77.000000  -77.000000      -77.0  -77.00000
# 1      -77.0 -77.000000 -77.000000  -77.000000      -77.0  -77.00000
# 2      -77.0 -77.000000 -77.000000  -77.000000      -77.0    0.33411
# 3      -77.0 -77.000000 -77.000000  -77.000000      -77.0  -77.00000
# 4      -77.0 -77.000000   3.500385  -77.000000      -77.0  -77.00000
# ..       ...        ...        ...         ...        ...        ...
# 545    -77.0 -77.000000   0.553057    3.966308      -77.0  -77.00000
# 546    -77.0   3.950046   1.037017    4.503547      -77.0  -77.00000
# 547    -77.0   3.714171 -77.000000  279.584302      -77.0  -77.00000
# 548    -77.0 -77.000000 -77.000000  -77.000000      -77.0  -77.00000
# 549    -77.0 -77.000000 -77.000000  -77.000000      -77.0  -77.00000
#
#      brtz_mass  docx_mass  pacx_mass
# 0        -77.0      -77.0  -77.00000
# 1        -77.0      -77.0  -77.00000
# 2        -77.0      -77.0  -77.00000
# 3        -77.0      -77.0  -77.00000
# 4        -77.0      -77.0  -77.00000
# ..         ...        ...        ...
# 545      -77.0      -77.0    0.51911
# 546      -77.0      -77.0  -77.00000
# 547      -77.0      -77.0  -77.00000
# 548      -77.0      -77.0  -77.00000
# 549      -77.0      -77.0  -77.00000
#
# [550 rows x 14 columns]

# %%
df_top_5_surfaces['p_surfaceID'] = df_top_5_surfaces['p_surfaceID'].replace({'bsc':'Biological Safety Cabinet'}).replace({'n_key':'Patient Administration Keyboards'}).replace({'pt_side': 'Patient Side Table'}).replace({'pt_surf': 'Pass-through Surface Tray'}).replace({'n_cnt': 'Counters by Nurse Desk and Workspaces'})

df_top_5_surfaces['site'] = df_top_5_surfaces['site'].replace({'Edm':'Edmonton'})
df_top_5_surfaces['site'] = df_top_5_surfaces['site'].replace({'FMM':'Fort McMurray'})
df_top_5_surfaces['site'] = df_top_5_surfaces['site'].replace({'HR':'High River'})
df_top_5_surfaces['site'] = df_top_5_surfaces['site'].replace({'Med Hat':'Medicine Hat'})
df_top_5_surfaces['site'] = df_top_5_surfaces['site'].replace({'MCC':'Masonic'})
df_top_5_surfaces['site'] = df_top_5_surfaces['site'].replace({'UMMC':'UMN Inpatient'})

# %%
gem = df_top_5_surfaces.filter(items=['site','surface','p_surfaceID','gem_mass'])
gem_filtered = gem.drop(gem[gem['gem_mass'] == -77.000000].index)
gem_filtered
# Out:
#               site                   surface  \
# 10        Edmonton           Nursing counter
# 12        Edmonton          BSC work surface
# 13        Edmonton          Passthrough tray
# 15        Edmonton           Nursing counter
# 18        Edmonton            Steel med tray
# ..             ...                       ...
# 519  UMN Inpatient      workstation keyboard
# 522  UMN Inpatient         plastic chemo bin
# 527  UMN Inpatient                       BSC
# 529  UMN Inpatient              storage cart
# 542  UMN Inpatient  nurse station counter #1
#
#                                p_surfaceID   gem_mass
# 10   Counters by Nurse Desk and Workspaces   0.114330
# 12               Biological Safety Cabinet   1.124985
# 13               Pass-through Surface Tray  26.027280
# 15   Counters by Nurse Desk and Workspaces   0.064380
# 18               Pass-through Surface Tray   0.513375
# ..                                     ...        ...
# 519       Patient Administration Keyboards   0.150682
# 522              Pass-through Surface Tray   0.187035
# 527              Biological Safety Cabinet   0.251415
# 529                     Patient Side Table   0.072100
# 542  Counters by Nurse Desk and Workspaces   0.089100
#
# [106 rows x 4 columns]

# %%
ifos = df_top_5_surfaces.filter(items=['site','surface','p_surfaceID','ifos_mass'])
ifos_filtered = ifos.drop(ifos[ifos['ifos_mass'] == -77.000000].index)
ifos_filtered
# Out:
#               site                       surface  \
# 4         Edmonton  Nursing workstation keyboard
# 184  Fort McMurray              passthrough tray
# 278  Grande Prarie  Nursing workstation keyboard
# 429        Masonic              BSC work surface
# 434        Masonic           BSC work surface #1
# 437        Masonic           BSC work surface #2
# 438        Masonic           BSC work surface #3
# 449        Masonic              BSC work surface
# 454        Masonic              BSC work surface
# 455        Masonic          pass through surface
# 456        Masonic                   plastic bin
# 460        Masonic              BSC work surface
# 465        Masonic                        BSC #1
# 466        Masonic                        BSC #2
# 467        Masonic                        BSC #3
# 478        Masonic                           BSC
# 483        Masonic                           BSC
# 484        Masonic           passthrough surface
# 489        Masonic                        BSC #4
# 490  UMN Inpatient     passthrough metal surface
# 491  UMN Inpatient             plastic chemo bin
# 492  UMN Inpatient                           BSC
# 496  UMN Inpatient             plastic chemo bin
# 497  UMN Inpatient                           BSC
# 509  UMN Inpatient              passthrough tray
# 511  UMN Inpatient          plastic chemo bin #2
# 512  UMN Inpatient          plastic chemo bin #3
# 513  UMN Inpatient                        BSC #1
# 514  UMN Inpatient                        BSC #2
# 515  UMN Inpatient                        BSC #3
# 516  UMN Inpatient           passthrough surface
# 517  UMN Inpatient             plastic chemo bin
# 518  UMN Inpatient                           BSC
# 521  UMN Inpatient           passthrough surface
# 522  UMN Inpatient             plastic chemo bin
# 526  UMN Inpatient           passthrough surface
# 527  UMN Inpatient                           BSC
# 530  UMN Inpatient            passthough surface
# 531  UMN Inpatient          plastic chemo bin #1
# 532  UMN Inpatient          plastic chemo bin #2
# 533  UMN Inpatient          plastic chemo bin #3
# 534  UMN Inpatient                        BSC #1
# 535  UMN Inpatient                        BSC #2
# 536  UMN Inpatient                        BSC #3
# 545  UMN Inpatient           passthrough surface
# 546  UMN Inpatient             plastic chemo bin
#
#                           p_surfaceID    ifos_mass
# 4    Patient Administration Keyboards     3.500385
# 184         Pass-through Surface Tray     0.526695
# 278  Patient Administration Keyboards     1.699410
# 429         Biological Safety Cabinet    12.459195
# 434         Biological Safety Cabinet     7.522470
# 437         Biological Safety Cabinet    10.351305
# 438         Biological Safety Cabinet     4.240755
# 449         Biological Safety Cabinet     8.688525
# 454         Biological Safety Cabinet   132.744345
# 455         Pass-through Surface Tray     1.955820
# 456         Pass-through Surface Tray     0.523920
# 460         Biological Safety Cabinet     0.542235
# 465         Biological Safety Cabinet    57.305415
# 466         Biological Safety Cabinet    86.730960
# 467         Biological Safety Cabinet    73.243905
# 478         Biological Safety Cabinet     4.744695
# 483         Biological Safety Cabinet     2.716725
# 484         Pass-through Surface Tray     0.800865
# 489         Biological Safety Cabinet   117.930840
# 490         Pass-through Surface Tray     2.708400
# 491         Pass-through Surface Tray     2.016315
# 492         Biological Safety Cabinet  1862.550030
# 496         Pass-through Surface Tray     0.813075
# 497         Biological Safety Cabinet   202.041090
# 509         Pass-through Surface Tray     1.504050
# 511         Pass-through Surface Tray     0.551670
# 512         Pass-through Surface Tray     0.946275
# 513         Biological Safety Cabinet     1.123320
# 514         Biological Safety Cabinet     1.513485
# 515         Biological Safety Cabinet     8.982120
# 516         Pass-through Surface Tray     0.925740
# 517         Pass-through Surface Tray     1.660005
# 518         Biological Safety Cabinet     1.181595
# 521         Pass-through Surface Tray     0.611610
# 522         Pass-through Surface Tray     5.622705
# 526         Pass-through Surface Tray     0.769230
# 527         Biological Safety Cabinet    13.624695
# 530         Pass-through Surface Tray     2.405370
# 531         Pass-through Surface Tray     2.800530
# 532         Pass-through Surface Tray     3.199020
# 533         Pass-through Surface Tray     5.717610
# 534         Biological Safety Cabinet     8.053050
# 535         Biological Safety Cabinet   308.923545
# 536         Biological Safety Cabinet     3.384390
# 545         Pass-through Surface Tray     0.553057
# 546         Pass-through Surface Tray     1.037017

# %%
vinc = df_top_5_surfaces.filter(items=['site','surface','p_surfaceID','vinc_mass'])
vinc_filtered = vinc.drop(vinc[vinc['vinc_mass'] == -77.000000].index)
vinc_filtered
# Out:
#               site                              surface  \
# 27        Edmonton                        charting area
# 46        Edmonton  St. 40 inpatient unit charting area
# 76         Calgary                     BSC work surface
# 82         Calgary           BSC #1 work surface (left)
# 95         Calgary                        Side Table #3
# 105        Calgary                      passthroughtray
# 110        Calgary                     passthrough tray
# 130        Calgary      nursing workstation keyboard #4
# 144        Calgary                   BSC worksurface #1
# 164  Fort McMurray                   BSC work surface 2
# 166  Fort McMurray                    pass through tray
# 171  Fort McMurray                          side table
# 179  Fort McMurray                     passthrough tray
# 190  Fort McMurray                      nursing counter
# 258  Grande Prarie                clear document sleeve
# 358   Medicine Hat                        side table #2
# 369         Ridges          nurse's counter by pharmacy
# 379         Ridges                  BSC work surface #2
# 431        Masonic                          plastic bin
# 432        Masonic                         storage cart
# 514  UMN Inpatient                               BSC #2
# 521  UMN Inpatient                  passthrough surface
#
#                                p_surfaceID  vinc_mass
# 27   Counters by Nurse Desk and Workspaces   0.110977
# 46   Counters by Nurse Desk and Workspaces   0.125296
# 76               Biological Safety Cabinet   0.483960
# 82               Biological Safety Cabinet   0.114145
# 95                      Patient Side Table   0.146890
# 105              Pass-through Surface Tray   0.069375
# 110              Pass-through Surface Tray   0.197303
# 130       Patient Administration Keyboards   0.076775
# 144              Biological Safety Cabinet   0.076775
# 164              Biological Safety Cabinet   0.067710
# 166              Pass-through Surface Tray   0.118770
# 171                     Patient Side Table   0.125835
# 179              Pass-through Surface Tray   0.071734
# 190  Counters by Nurse Desk and Workspaces   0.232545
# 258  Counters by Nurse Desk and Workspaces   0.079920
# 358                     Patient Side Table   0.092130
# 369  Counters by Nurse Desk and Workspaces   0.380175
# 379              Biological Safety Cabinet   0.288600
# 431              Pass-through Surface Tray   0.280275
# 432                     Patient Side Table   0.160395
# 514              Biological Safety Cabinet   0.225885
# 521              Pass-through Surface Tray   0.154845

# %%
docx = df_top_5_surfaces.filter(items=['site','surface','p_surfaceID','docx_mass'])
docx_filtered = docx.drop(docx[docx['docx_mass'] == -77.000000].index)
docx_filtered
# Out:
#               site                           surface  \
# 12        Edmonton                  BSC work surface
# 13        Edmonton                  Passthrough tray
# 19        Edmonton                     Bedside table
# 20        Edmonton  Charting area in nursing station
# 47        Edmonton                  BSC work Surface
# 48        Edmonton                  passthrough tray
# 77         Calgary                 pass-through tray
# 78         Calgary                   nursing counter
# 188  Fort McMurray                   BSC worksurface
# 258  Grande Prarie             clear document sleeve
# 353   Medicine Hat      nursing workstation keyboard
# 367         Ridges                  BSC work surface
# 373         Ridges                  BSC work surface
# 401         Ridges                            BSC #1
# 402         Ridges                            BSC #2
# 403         Ridges                            BSC #3
# 419         Ridges                               BSC
# 429        Masonic                  BSC work surface
# 434        Masonic               BSC work surface #1
# 437        Masonic               BSC work surface #2
# 438        Masonic               BSC work surface #3
# 449        Masonic                  BSC work surface
# 454        Masonic                  BSC work surface
# 466        Masonic                            BSC #2
# 478        Masonic                               BSC
#
#                                p_surfaceID  docx_mass
# 12               Biological Safety Cabinet   0.172605
# 13               Pass-through Surface Tray   0.276390
# 19                      Patient Side Table   0.504125
# 20   Counters by Nurse Desk and Workspaces   1.276390
# 47               Biological Safety Cabinet   0.181300
# 48               Pass-through Surface Tray   0.376660
# 77               Pass-through Surface Tray   0.322835
# 78   Counters by Nurse Desk and Workspaces   0.669330
# 188              Biological Safety Cabinet   0.208125
# 258  Counters by Nurse Desk and Workspaces   6.510150
# 353       Patient Administration Keyboards   0.653568
# 367              Biological Safety Cabinet   0.458430
# 373              Biological Safety Cabinet   2.997555
# 401              Biological Safety Cabinet   0.479187
# 402              Biological Safety Cabinet   0.789432
# 403              Biological Safety Cabinet   0.531912
# 419              Biological Safety Cabinet   3.215670
# 429              Biological Safety Cabinet   4.938945
# 434              Biological Safety Cabinet   6.315900
# 437              Biological Safety Cabinet   8.038620
# 438              Biological Safety Cabinet   2.807745
# 449              Biological Safety Cabinet  72.844305
# 454              Biological Safety Cabinet   0.498482
# 466              Biological Safety Cabinet   3.513150
# 478              Biological Safety Cabinet   5.199795

# %%
cycl = df_top_5_surfaces.filter(items=['site','surface','p_surfaceID','cycl_mass'])
cycl_filtered = cycl.drop(cycl[cycl['cycl_mass'] == -77.000000].index)
cycl_filtered
# Out:
#               site                   surface  \
# 12        Edmonton          BSC work surface
# 13        Edmonton          Passthrough tray
# 15        Edmonton           Nursing counter
# 16        Edmonton                Side table
# 19        Edmonton             Bedside table
# ..             ...                       ...
# 536  UMN Inpatient                    BSC #3
# 543  UMN Inpatient  nurse station counter #2
# 545  UMN Inpatient       passthrough surface
# 546  UMN Inpatient         plastic chemo bin
# 547  UMN Inpatient                       BSC
#
#                                p_surfaceID   cycl_mass
# 12               Biological Safety Cabinet    1.227105
# 13               Pass-through Surface Tray    0.831390
# 15   Counters by Nurse Desk and Workspaces    0.358530
# 16                      Patient Side Table    0.382395
# 19                      Patient Side Table    2.319345
# ..                                     ...         ...
# 536              Biological Safety Cabinet  217.574430
# 543  Counters by Nurse Desk and Workspaces   11.047275
# 545              Pass-through Surface Tray    3.966308
# 546              Pass-through Surface Tray    4.503547
# 547              Biological Safety Cabinet  279.584302
#
# [90 rows x 4 columns]

# %% [markdown]
# ## 4. Visualizing the Data

# %%
gem_bar = alt.Chart(gem_filtered).mark_bar().encode(
    x = alt.X('p_surfaceID', axis=alt.Axis(labelAngle=-45)).title('Surface Type'),
    y = alt.Y('gem_mass').title('Gemcitabine Mass (ng)'),
        color='site'
    ).properties(
        width=100, 
        height=500,
    ).facet('site', title='Amount of Gemcitabine Sampled on Commonly Detected Surface Areas')

gem_bar
# Out:
# alt.FacetChart(...)

# %%
ifos_bar = alt.Chart(ifos_filtered).mark_bar().encode(
    x = alt.X('p_surfaceID', axis=alt.Axis(labelAngle=-45)).title('Surface Type'),
    y = alt.Y('ifos_mass').title('Ifosfamide Mass (ng)'),
        color='site'
    ).properties(
        width=100, 
        height=500
    ).facet('site', title='Amount of Ifosfamide Sampled on Commonly Detected Surface Areas')

ifos_bar
# Out:
# alt.FacetChart(...)

# %%
vinc_bar = alt.Chart(vinc_filtered).mark_bar().encode(
    x = alt.X('p_surfaceID', axis=alt.Axis(labelAngle=-45)).title('Surface Type'),
    y = alt.Y('vinc_mass').title('Vincristine Mass'),
        color='site'
    ).properties(
        width=100, 
        height=500
    ).facet('site', title='Amount of Vincristine (ng) Sampled on Commonly Detected Surface Areas')

vinc_bar
# Out:
# alt.FacetChart(...)

# %%
docx_bar = alt.Chart(docx_filtered).mark_bar().encode(
    x = alt.X('p_surfaceID', axis=alt.Axis(labelAngle=-45)).title('Surface Type'),
    y = alt.Y('docx_mass').title('Docetaxel Mass'),
        color='site'
    ).properties(
        width=100, 
        height=500
    ).facet('site', title='Amount of Docetaxel (ng) Sampled on Commonly Detected Surface Areas')

docx_bar
# Out:
# alt.FacetChart(...)

# %%
cycl_bar = alt.Chart(cycl_filtered).mark_bar().encode(
    x = alt.X('p_surfaceID', axis=alt.Axis(labelAngle=-45)).title('Surface Type'),
    y = alt.Y('cycl_mass').title('Cyclophosphamide Mass (ng)'),
        color='site'
    ).properties(
        width=100, 
        height=500
    ).facet('site', title='Amount of Cyclophosphamide Sampled on Commonly Detected Surface Areas')

cycl_bar
# Out:
# alt.FacetChart(...)

# %% [markdown]
# # Discussion

# %% [markdown]
# Investigating the AD exposure levels on common surfaces at these facilities, the research project began by reducing the original dataset columns to the following ('site','surface','p_surfaceID', 'gem_mass', 'fu_mass', 'ox_mass', 'mtrx_mass', 'ifos_mass', 'cycl_mass','vinc_mass', 'vinb_mass', 'brtz_mass', 'docx_mass', and 'pacx_mass'). Despite retaining all of the recorded antineoplastic agents from the database, this project solely focused the detected amounts of gemcitabine, ifosfamide, cyclophosphamide, vincristine, and docetaxel. For data cleaning and summarization purposes, visualized dataframes only included records that involved the top five most commonly contaminated surfaces types ('n_key', 'bsc', 'pt_side', 'pt_surf', and 'n_cnt') in the 'p_surfaceID' field.
#
# While Biological Safety Cabinets often outnumbered the other four surface types on detected amounts of ADs, this research has provided some key insights about exposures for each of the nine sites:
#
# ##### - The highest amount cytotoxic drug detected was roughly 13,500 ng of Cyclophosphamide in the Biological Safety Cabinet at UMN Inpatient location, followed by 4,500 at Masonic facility.
#
# ##### - Vincristine was the most commonly detected agent, with contaminations at eight of the nine participating sites, most notably at Calgary, Fort McMurray, and Ridges.
#
#
# To refine future results, the research can also consider other factors such as clinic workload, the reported number of patients receiving chemotherapy on the day prior and of sampling, and information on surface spills.
#
# Overall, these findings could influence medical practice, workplace safety measures, and research funding, raising awareness to the detrimental effects of long-term exposure to antineoplastic drugs for healthcare employees.

# %% [markdown]
# # Conclusion

# %% [markdown]
# In summary, our research aimed to examine which antineoplastic agents were found on commonly contaminated workplace surfaces for the participating nine sites. In completion of this descriptive analysis, we conclude that the Cyclophosphamide agent had the largest amount present on contaminated site surfaces, and that most locations had a common exposure to Vincristine. Although this analysis is limited to a few observations, it highlights significant health risks for workers. Some of the potential hazards include cancer, organ toxicity, and reproductive issues. This project underscores the critical need for monitoring antineoplastic drug contamination to protect healthcare employees. Enhanced safety measures and continuous evaluation are essential to mitgate these risks.

# %% [markdown]
# # References

# %% [markdown]
# 1. Alsaied, T., Tremoulet, A. H., Burns, J. C., Saidi, A., Dionne, A., Lang, S. M., ... & Fraisse, A. (2021). Multisystem inflammatory syndrome in children during the COVID-19 pandemic: A systematic review of published case studies. Journal of the American Heart Association, 10(11), e019259. https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5599271/
#
# 2. Centers for Disease Control and Prevention. (n.d.). Antineoplastic agents and occupational exposure. National Institute for Occupational Safety and Health. https://www.cdc.gov/niosh/healthcare/risk-factors/antineoplastic-agents.html
#
# 3. Occupational Cancer Research Centre. (2014). Antineoplastics and Cancer. Occupational Cancer Research Centre. https://www.occupationalcancer.ca/wp-content/uploads/2014/07/Antineoplastics-and-cancer-ENG.pdf
#
# 4. Patel, A., Agarwal, R., Rudramurthy, S. M., Shevkani, M., Xess, I., Sharma, R., ... & Chakrabarti, A. (2021). Clinical characterization and outcomes of patients with COVID-19-associated mucormycosis: A multicenter cohort study. PLOS ONE, 16(6), e0252468. https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8952240/
